# %%
# Importa la biblioteca pandas y la asigna al alias pd, para manejo de datos en estructuras tipo tabla.
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
df = pd.read_csv("ACTIVIDADES_DE_LA_BIBLIOTECA_clean.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15309 entries, 0 to 15308
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Actividad          15309 non-null  object
#  1   Línea_Servicio     15309 non-null  object
#  2   ESPACIO_ACTIVIDAD  15309 non-null  object
#  3   Asistencias        15309 non-null  int64
#  4   Rangos_Edad        15309 non-null  object
#  5   LUGAR              15309 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 717.7+ KB

# %%
df.shape
# Out:
# (15309, 6)

# %%
df.Asistencias.value_counts().sort_index()
# Out:
# Asistencias
# 1      12279
# 2        681
# 3        395
# 4        229
# 5        224
#        ...
# 280        1
# 344        1
# 351        1
# 360        1
# 385        1
# Name: count, Length: 106, dtype: int64

# %%
# Se carga el archivo limpio
df = pd.read_csv("ACTIVIDADES_DE_LA_BIBLIOTECA_clean.csv")

# %%
# 1. Histograma de acuerdo a la frecuencia de Asistencias a la Bibioteca

# Etiquetas y titulos


plt.hist(df["Asistencias"], bins=20)
plt.title("Distribución de Asistencias")
plt.xlabel("Número de Asistencias")
plt.ylabel("Frecuencia")

# Hiatograma segun la cantidad de columnas
n, bins, patches = plt.hist(df.Asistencias, color="skyblue", edgecolor='black')

#Mostrar Histograma
plt.show()

# %%
# 2. Histograma de frecuencia de actividades por rango de edad

# Etiquetas y titulos


df['Rangos_Edad'].value_counts().plot(kind='bar', color='green', edgecolor='black')
plt.title("Frecuencia de Actividades por Rangos de Edad")
plt.xlabel("Rango de Edad")
plt.ylabel("Asistentes a las Actividades")
plt.tight_layout()

#Mostrar Histograma
plt.show()

# %%
# Using Pandas directly to get a histogram
df.plot.hist(column="Asistencias", by="LUGAR")
# Out:
# array([<Axes: title={'center': 'BOJACÁ'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'CENTRO'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'FAGUA'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'JJ. CASAS'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'LA BALSA'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'MERCEDES'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'MERCEDES DE C'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'RESGUARDO'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'YERBABUENA'}, ylabel='Frequency'>],
#       dtype=object)

# %%
# Cantidad de asistencias a las distintas actividades

df.plot.hist(column="Asistencias", by="Línea_Servicio", figsize=(8,24))
# Out:
# array([<Axes: title={'center': 'ACCESO A INTERNET'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'ACTIVIDADES DE FORMACION CULTURAL'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'ACTIVIDADES DE FORMACION EN LECTURA Y ESCRITURA'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'ACTIVIDADES DE FORMACIÓN EN LECTURA'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'ACTIVIDADES EN LECTURA Y ESCRITURA'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'ACTIVIDADES Y FORMACION COMUNITARIA'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'ACTIVIDADES Y FORMACION COMUNITARIA PARA EL DESARROLLO LOCAL'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'AREA DE CIRCULACION Y PRESTAMO'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'CONSULTA EN SALA'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'FORMACIÓN DE USUARIOS / ALFABETIZACIÓN INFORMACIONAL'}, ylabel='Frequency'>,
# ...
